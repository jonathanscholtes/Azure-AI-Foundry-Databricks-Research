# %%
! pip install -r requirements.txt --quiet

# %% [markdown]
# # Semantic Kernel Sequential Orchestration
#
# In sequential orchestration, agents are organized in a pipeline. Each agent processes the task in turn, passing its output to the next agent in the sequence.
#
# 🔗 [Sequential Orchestration](https://learn.microsoft.com/en-us/semantic-kernel/frameworks/agent/agent-orchestration/sequential?pivots=programming-language-python)

# %% [markdown]
# <img src="../../media/multi-agent-sequential.png" alt="Diagram" style="height:450px; width:auto;">

# %%
from semantic_kernel.agents import SequentialOrchestration
from semantic_kernel import Kernel
from semantic_kernel.agents import ChatCompletionAgent,ChatHistoryAgentThread
from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion
from dotenv import load_dotenv
from os import environ
import asyncio
from user_plugins import SalesPlugin
from tracing import set_up_all

load_dotenv(override=True)

kernel = Kernel()

# %%
set_up_all(connection_string=environ.get("AZURE_INSIGHT_CONNECTION_STRING"))

# %%
chatCompletion = AzureChatCompletion(
    service_id="chat",
    deployment_name=environ["AZURE_OPENAI_MODEL"],
    endpoint=environ["AZURE_OPENAI_ENDPOINT"],
    api_key=environ["AZURE_OPENAI_API_KEY"],
     api_version=environ["AZURE_OPENAI_API_VERSION"] )


reasoningCompletion = AzureChatCompletion(
    service_id="reasoning",
    deployment_name='o3-mini',
    endpoint=environ["AZURE_OPENAI_ENDPOINT"],
    api_key=environ["AZURE_OPENAI_API_KEY"],
     api_version=environ["AZURE_OPENAI_API_VERSION"] )

# %%
# Sales Data Agent
sales_data_agent = ChatCompletionAgent(
    name="SalesDataAgent",
    instructions=(
        """You are a Sales Data Agent. Your job is to:
        - Dynamically choose and call the appropriate tool(s) to answer user questions about sales, customers, or products.
        - Always include customer names alongside IDs in any output.
        - Always display monetary amounts in $USD (e.g., $123.45).
        - Use filters and aggregations as needed to generate insights from sales orders, products, and customers.
        - Compute totals, revenue, discounts, and other metrics from nested order data.
        - Return **complete, detailed outputs** without summarization, so that all data is available for downstream analysis.
        - Preserve all intermediate results and raw values in your response.
        - Avoid hardcoding analytics; rely on the MCP tools and their parameters.
        - Clarify ambiguous queries before performing analysis.
        - Do not ask the user follow-up questions; only return the requested records.
        - Treat the tools as the source of truth; do not expose raw database internals.
        - return output in table format when possible for consumption by the next agent.
        """
    ),
    plugins=[SalesPlugin],
    service=chatCompletion,
)

# Data Analysis Agent
data_analysis_agent = ChatCompletionAgent(
    name="DataAnalysisAgent",
    instructions=(
        """You are a Data Analysis Agent. Given the sales data, your job is to:
        - Analyze and interpret the sales data provided by the SalesDataAgent.
        - Identify trends, patterns, and insights from the sales data.
        - Provide actionable recommendations based on the analysis.
        - Summarize key findings in a clear and concise manner.
        - Ensure that all analyses are relevant to the user's query and objectives.
        - Provide Key Findings, Insights, Trends, Recommendations and a Summary in your final output.
        """
    ),
      service=reasoningCompletion,
)

# %% [markdown]
# ### Optional: Observe Agent Responses

# %%
from semantic_kernel.contents import ChatMessageContent

def agent_response_callback(message: ChatMessageContent) -> None:
    print(f"# {message.name}\n{message.content}")

# %% [markdown]
# ### Set Up the Sequential Orchestration

# %%
agents = [sales_data_agent, data_analysis_agent]
sequential_orchestration = SequentialOrchestration(
    members=agents,
    agent_response_callback=agent_response_callback,
)

# %% [markdown]
# ### Start the Runtime

# %%
from semantic_kernel.agents.runtime import InProcessRuntime

runtime = InProcessRuntime()
runtime.start()
# Out:
# # SalesDataAgent
#
# # SalesDataAgent
#
# # SalesDataAgent
# To find the top 5 customers based on the number of orders, the sales order data is analyzed to count the orders for each customer.
#
# ### Step 1: Count Orders Per Customer
# From the sales data, the following order counts per customer are determined:
#
# | Customer ID | Customer Name | Order Count |
# |-------------|---------------|-------------|
# | 4           | NAPA          | 17          |
# | 2           | AutoZone      | 15          |
# | 1           | GM            | 13          |
# | 3           | Bosch         | 7           |
# | 0           | Ford          | 6           |
#
# ### Top 5 Customers
# The top 5 customers by order count are:
# 1. **NAPA** with 17 orders
# 2. **AutoZone** with 15 orders
# 3. **GM** with 13 orders
# 4. **Bosch** with 7 orders
# 5. **Ford** with 6 orders
#
# Let's now dig deeper into the purchasing behavior of these customers to provide actionable insights.
#
# ---
#
# ### Step 2: Analyze Purchasing Behavior
# For each of the top 5 customers, metrics like total quantity purchased, total revenue, and most frequently ordered products are calculated.
#
# #### **Customer: NAPA**
# - **Total Revenue**: $51,467.23
# - **Total Quantity Purchased**: 1,665 units
# - **Most Frequently Purchased Product**: Brake Pad (804 units)
# - **Regions of Purchase**: NA, EU
# - **Key Insight**: NAPA frequently purchases large quantities of brake pads. Promoting discounts on bulk orders of brake-related products could drive higher sales.
#
# #### **Customer: AutoZone**
# - **Total Revenue**: $38,814.72
# - **Total Quantity Purchased**: 1,103 units
# - **Most Frequently Purchased Product**: Oil Filter (411 units)
# - **Regions of Purchase**: NA, EU
# - **Key Insight**: AutoZone shows strong interest in oil filters. Highlight promotional campaigns for complementary items like spark plugs could increase cross-selling.
#
# #### **Customer: GM**
# - **Total Revenue**: $45,237.71
# - **Total Quantity Purchased**: 1,128 units
# - **Most Frequently Purchased Product**: Spark Plug (584 units)
# - **Regions of Purchase**: NA, EU
# - **Key Insight**: GM favors spark plugs. Offering loyalty programs for this product category or bundling spark plugs with other related products could boost revenue.
#
# #### **Customer: Bosch**
# - **Total Revenue**: $24,891.97
# - **Total Quantity Purchased**: 681 units
# - **Most Frequently Purchased Product**: Brake Pad (377 units)
# - **Regions of Purchase**: NA, EU
# - **Key Insight**: Bosch is primarily focused on brake pads. Strengthening relationships by offering tailored solutions and exclusive contracts for brake pad supply can be effective.
#
# #### **Customer: Ford**
# - **Total Revenue**: $19,124.56
# - **Total Quantity Purchased**: 524 units
# - **Most Frequently Purchased Product**: Brake Pad (346 units)
# - **Regions of Purchase**: NA, EU
# - **Key Insight**: Ford's purchases are concentrated on brake pads. Promoting a subscription model for regular replenishment of brake pads could be beneficial.
#
# ---
#
# ### Recommended Actions:
# 1. **Bulk Discounts for Frequent Customers**: Introduce tiered discounts for NAPA on large orders of brake pads.
# 2. **Cross-Selling Campaigns**: For AutoZone and GM, increase marketing of spark plugs and related accessories.
# 3. **Loyalty Programs**: Reward frequent purchases from GM and Bosch to encourage repeat business.
# 4. **Regional Promotions**: Dynamically target customers based on regions (e.g., EU-focused offers for Bosch and Ford).
# 5. **Exclusive Contracts**: Work with Bosch to explore exclusive contracts for high-volume brake pad orders.
#
# Let me know if you'd like a deeper dive into any specific customer or category!
# # DataAnalysisAgent
# Below is a comprehensive analysis of the top 5 customers along with key findings, insights, trends, actionable recommendations, and a summary based on the provided sales data.
#
# ─────────────────────────────
# Key Findings:
# ─────────────────────────────
# • The top 5 customers by order count are:
#   – NAPA: 17 orders
#   – AutoZone: 15 orders
#   – GM: 13 orders
#   – Bosch: 7 orders
#   – Ford: 6 orders
# • Total revenue, total quantity purchased, and preferred product categories vary among these customers.
# • Customers from regions NA and EU are present, indicating regional opportunities for targeted promotions.
#
# ─────────────────────────────
# Insights:
# ─────────────────────────────
# • NAPA, with the highest order count, generated a revenue of $51,467.23 on 1,665 units—displaying a strong affinity for Brake Pads (804 units purchased).
# • AutoZone, earning $38,814.72 over 1,103 units, shows clear preference for Oil Filters (411 units purchased), suggesting potential for cross-selling complementary items such as spark plugs.
# • GM’s 13 orders resulted in $45,237.71 on 1,128 units with a dominant focus on Spark Plugs (584 units purchased), making it a prime target for loyalty or bundling programs.
# • Bosch and Ford, while lower in order counts and revenue ($24,891.97 and $19,124.56 respectively), primarily purchase Brake Pads (377 units for Bosch and 346 units for Ford). This indicates that exclusive deals or subscription-based offerings could be highly effective.
#
# ─────────────────────────────
# Trends:
# ─────────────────────────────
# • There is a noticeable trend in product focus: Brake Pads are popular for NAPA, Bosch, and Ford; Oil Filters dominate for AutoZone; and Spark Plugs lead for GM.
# • Despite varying order counts, all top customers purchase primarily within the NA and EU regions, implying regional market similarities.
# • Frequent, large quantity orders among top customers indicate that discount tiers or loyalty incentives could further increase volume and revenue growth.
#
# ─────────────────────────────
# Recommendations:
# ─────────────────────────────
# 1. Bulk Discounts & Tiered Pricing:
#    – Offer personalized bulk discounts for customers like NAPA, Bosch, and Ford, particularly on Brake Pads.
# 2. Cross-Selling Opportunities:
#    – For AutoZone, consider promoting complementary products like spark plugs or other related automotive accessories.
# 3. Loyalty Programs & Bundling:
#    – Introduce loyalty rewards or bundle offers for GM, especially focusing on Spark Plugs to incentivize repeat orders.
# 4. Regional Promotional Campaigns:
#    – Leverage the NA and EU market data to design targeted promotions unique to each region, which may also be applicable to other similar markets.
# 5. Exclusive Supply Contracts:
#    – For customers such as Bosch, explore long-term or exclusive contracts, which could secure steady revenue and deepen customer relationships.
#
# ─────────────────────────────
# Summary:
# ─────────────────────────────
# The analysis reveals that NAPA, AutoZone, GM, Bosch, and Ford command significant order volumes and display distinct purchasing preferences—with Brake Pads, Oil Filters, and Spark Plugs being the key products. By implementing bulk discounts, targeted cross-selling initiatives, loyalty programs, and region-specific promotions, businesses can enhance customer retention and drive additional revenue. Focusing on exclusive contracts and subscription-based offerings—especially for customers with concentrated product categories—will further solidify these key business relationships.
#
# These insights and recommendations can be leveraged to fine-tune sales strategies, optimize marketing efforts, and ultimately boost overall sales performance across the board.
#
# Feel free to ask for further analysis or a deeper dive into individual customer behaviors or product categories if needed!

# %%
orchestration_result = await sequential_orchestration.invoke(
    task="Find the top 5 customers by number of orders, and bring back order and analyze their purchasing behavior to provide actionable insights for increasing sales.",
    runtime=runtime,
)

# %%
value = await orchestration_result.get(timeout=30)
print(f"***** Final Result *****\n{value}")
# Out:
# ***** Final Result *****
# Below is a comprehensive analysis of the top 5 customers along with key findings, insights, trends, actionable recommendations, and a summary based on the provided sales data.
#
# ─────────────────────────────
# Key Findings:
# ─────────────────────────────
# • The top 5 customers by order count are:
#   – NAPA: 17 orders
#   – AutoZone: 15 orders
#   – GM: 13 orders
#   – Bosch: 7 orders
#   – Ford: 6 orders
# • Total revenue, total quantity purchased, and preferred product categories vary among these customers.
# • Customers from regions NA and EU are present, indicating regional opportunities for targeted promotions.
#
# ─────────────────────────────
# Insights:
# ─────────────────────────────
# • NAPA, with the highest order count, generated a revenue of $51,467.23 on 1,665 units—displaying a strong affinity for Brake Pads (804 units purchased).
# • AutoZone, earning $38,814.72 over 1,103 units, shows clear preference for Oil Filters (411 units purchased), suggesting potential for cross-selling complementary items such as spark plugs.
# • GM’s 13 orders resulted in $45,237.71 on 1,128 units with a dominant focus on Spark Plugs (584 units purchased), making it a prime target for loyalty or bundling programs.
# • Bosch and Ford, while lower in order counts and revenue ($24,891.97 and $19,124.56 respectively), primarily purchase Brake Pads (377 units for Bosch and 346 units for Ford). This indicates that exclusive deals or subscription-based offerings could be highly effective.
#
# ─────────────────────────────
# Trends:
# ─────────────────────────────
# • There is a noticeable trend in product focus: Brake Pads are popular for NAPA, Bosch, and Ford; Oil Filters dominate for AutoZone; and Spark Plugs lead for GM.
# • Despite varying order counts, all top customers purchase primarily within the NA and EU regions, implying regional market similarities.
# • Frequent, large quantity orders among top customers indicate that discount tiers or loyalty incentives could further increase volume and revenue growth.
#
# ─────────────────────────────
# Recommendations:
# ─────────────────────────────
# 1. Bulk Discounts & Tiered Pricing:
#    – Offer personalized bulk discounts for customers like NAPA, Bosch, and Ford, particularly on Brake Pads.
# 2. Cross-Selling Opportunities:
#    – For AutoZone, consider promoting complementary products like spark plugs or other related automotive accessories.
# 3. Loyalty Programs & Bundling:
#    – Introduce loyalty rewards or bundle offers for GM, especially focusing on Spark Plugs to incentivize repeat orders.
# 4. Regional Promotional Campaigns:
#    – Leverage the NA and EU market data to design targeted promotions unique to each region, which may also be applicable to other similar markets.
# 5. Exclusive Supply Contracts:
#    – For customers such as Bosch, explore long-term or exclusive contracts, which could secure steady revenue and deepen customer relationships.
#
# ─────────────────────────────
# Summary:
# ─────────────────────────────
# The analysis reveals that NAPA, AutoZone, GM, Bosch, and Ford command significant order volumes and display distinct purchasing preferences—with Brake Pads, Oil Filters, and Spark Plugs being the key products. By implementing bulk discounts, targeted cross-selling initiatives, loyalty programs, and region-specific promotions, businesses can enhance customer retention and drive additional revenue. Focusing on exclusive contracts and subscription-based offerings—especially for customers with concentrated product categories—will further solidify these key business relationships.
#
# These insights and recommendations can be leveraged to fine-tune sales strategies, optimize marketing efforts, and ultimately boost overall sales performance across the board.
#
# Feel free to ask for further analysis or a deeper dive into individual customer behaviors or product categories if needed!

# %%
await runtime.stop_when_idle()
